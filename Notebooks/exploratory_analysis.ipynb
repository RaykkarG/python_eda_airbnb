# %% [markdown]
# ## Analise exploratória dos dados de Airbnb_Open_Data
#
# ### Briefing
# 1) Preço médio por neighbourhood
# 2) Preço médio por neighbourhood_group
# 3) Preço médio de service_fee por neighbourhood
# 4) grafico com count unique de cancellation_policy
# 5) count de host_identity_verified
# 6) Quantidade de id por ano

# %%
import pandas as pd
import numpy as np

# %%
df_original = pd.read_csv('../Data/processed/processed_Airbnb_Open_Data.csv', low_memory=False)
df = df_original.copy()

# %%
df.head()
# Out:
#    Unnamed: 0       id                                              name  \
# 0           0  1001254                Clean & quiet apt home by the park
# 1           1  1002102                             Skylit Midtown Castle
# 2           2  1003689  Entire Apt: Spacious Studio/Loft by central park
# 3           3  1004098         Large Cozy 1 BR Apartment In Midtown East
# 4           4  1005202                                   BlissArtsSpace!
#
#        host_id host_identity_verified host_name neighbourhood_group  \
# 0  80014485718            Unconfirmed  Madaline            Brooklyn
# 1  52335172823               Verified     Jenna           Manhattan
# 2  92037596077               Verified    Lyndon           Manhattan
# 3  45498551794               Verified  Michelle           Manhattan
# 4  90821839709            Unconfirmed      Emma            Brooklyn
#
#         neighbourhood       lat      long  ... country_code instant_bookable  \
# ...
